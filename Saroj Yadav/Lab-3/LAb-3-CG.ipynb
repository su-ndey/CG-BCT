# %% [markdown]
# ## Midpoint Circle Drawing Algorithm

# %%
import matplotlib.pyplot as plt
def plot(xes,yes,x,y,xc,yc): # function define
    
    xes.extend([x+xc,-x+xc,-x+xc,x+xc,y+xc,-y+xc,y+xc,-y+xc])
    yes.extend([y+yc,y+yc,-y+yc,-y+yc,x+yc,x+yc,-x+yc,-x+yc])
    


def MCA():

    r  = int(input("enter the radius:"))
    xc = int(input("enter the value of xc:"))       
    yc = int(input("enter the value of yc:"))
   
    x=0
    y=r
    p = 1-r # Initial decision parameter
    
    xes = []
    yes = []
    
    plot(xes,yes,x,y,xc,yc)
    
        

    while x < y:
        x = x+1 
        if p < 0:
            p = p + 2*x + 1

        else:
            y = y - 1
            p = p + 2*(x-y) + 1 

        plot(xes,yes,x,y,xc,yc)# plot function call
    
    plt.scatter(xes,yes,marker='*',label="Circle")# Plot each point after update
    plt.grid(True)
    plt.legend()
    plt.show()
    

MCA()
# Out:
# enter the radius: 5
# enter the value of xc: 5
# enter the value of yc: 5
